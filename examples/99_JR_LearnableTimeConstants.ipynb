# %% [markdown]
# # RNN with all the hacks & learnable TAUs

# %%
import os
import sys

sys.path.append("../../stork")

import numpy as np
import torch

import matplotlib.pyplot as plt
import seaborn as sns


import stork
from stork.datasets import HDF5Dataset, DatasetView

from stork.loss_stacks import SumOfSoftmaxCrossEntropy
from stork.layers import Layer
from stork.models import RecurrentSpikingModel
from stork.nodes import InputGroup, ReadoutGroup, LIFGroup, AdaptLearnLIFGroup
from stork.connections import Connection
from stork.generators import StandardGenerator
from stork.initializers import (
    FluctuationDrivenCenteredNormalInitializer,
    DistInitializer,
)

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# ***To locally run this notebook on your system, download the SHD dataset from: [https://zenkelab.org/datasets/](https://zenkelab.org/datasets/).***
# *We need 'shd_train.h5' and 'shd_test.h5'. Move the downloaded files into a folder `data/datasets/hdspikes` in this repo, or change the `datadir` variable below.

# %%
datadir = "/tungstenfs/scratch/gzenke/datasets/hdspikes"

# %% [markdown]
# Next, we specify the Dataset Parameters.

# %%
nb_inputs = 700
duration = 0.7
time_step = dt = 2e-3
nb_time_steps = int(duration / time_step)
time_scale = 1
unit_scale = 1
validation_split = 0.9

sigma_u_augment = 10
dropout_p = 0.4

# %%
train_gen_kwargs = dict(
    nb_steps=nb_time_steps,
    time_scale=time_scale / time_step,
    unit_scale=unit_scale,
    nb_units=nb_inputs,
    preload=True,
    precompute_dense=False,
    unit_permutation=None,
    sigma_u_uniform=sigma_u_augment,
)

test_gen_kwargs = dict(
    nb_steps=nb_time_steps,
    time_scale=time_scale / time_step,
    unit_scale=unit_scale,
    nb_units=nb_inputs,
    preload=True,
    precompute_dense=False,
    unit_permutation=None,
    sigma_u_uniform=0,
)

# %%
train_dataset = HDF5Dataset(os.path.join(datadir, "shd_train.h5"), **train_gen_kwargs)

# Split into train and validation set
mother_dataset = train_dataset
elements = np.arange(len(mother_dataset))
np.random.shuffle(elements)
split = int(validation_split * len(mother_dataset))
valid_dataset = DatasetView(mother_dataset, elements[split:])
train_dataset = DatasetView(mother_dataset, elements[:split])

test_dataset = HDF5Dataset(os.path.join(datadir, "shd_test.h5"), **test_gen_kwargs)

# %% [markdown]
# ## Set up the model

# %%
# Model Parameters
batch_size = 256
beta = 20
device = torch.device("cuda:0")
dtype = torch.float

nb_hidden_units = 1024
nb_hidden_layers = 1
nb_classes = 20

tau_mem = 20e-3
tau_syn = 10e-3
tau_readout = 200e-3

lr = 5e-3
nb_epochs = 100

# %%
act_fn = stork.activations.SuperSpike
act_fn.beta = beta
neuron_group = LIFGroup

model = RecurrentSpikingModel(batch_size, nb_time_steps, nb_inputs, device, dtype)

# %% [markdown]
# Create regularizers

# %%
# Define regularizer parameters (set regularizer strenght to 0, if you don't want to use them)
lowerBoundL2Strength = 100
lowerBoundL2Threshold = 1e-3
upperBoundL2Strength = 0
upperBoundL2Threshold = (
    7  # Regularizes spikecount: 7 spikes ~ 10 Hz in 700ms simulation time
)
weightL2Strength = 1e-4

# Define regularizer list
regs = []

regLB = stork.regularizers.LowerBoundL2(
    lowerBoundL2Strength, threshold=lowerBoundL2Threshold, dims=False
)
regs.append(regLB)
regUB = stork.regularizers.UpperBoundL2(
    upperBoundL2Strength, threshold=upperBoundL2Threshold, dims=1
)
#regs.append(regUB)

w_regs = []

regw = stork.regularizers.WeightL2Regularizer(strength=weightL2Strength)
w_regs.append(regw)

# %% [markdown]
# We initialize the network in the Flucutation-Driven regime, with a target membrane potential standard deviation $\sigma_U=1.0$

# %%
sigma_u = 0.7
nu = 15.8

initializer = FluctuationDrivenCenteredNormalInitializer(
    sigma_u=sigma_u, nu=nu, timestep=dt
)

readout_initializer = DistInitializer()

# %% [markdown]
# Add input neuron group

# %%
input_group = model.add_group(InputGroup(nb_inputs, dropout_p=dropout_p))

# %% [markdown]
# Now we want to add multiple hidden layers as well as regularizers for them

# %%
upstream_group = input_group

for l in range(nb_hidden_layers):

    hidden_layer = Layer(
        "hidden",
        model,
        nb_hidden_units,
        upstream_group,
        recurrent=True,
        regs=regs,
        w_regs=w_regs,
        neuron_class=neuron_group,
        neuron_kwargs=dict(
            tau_mem=tau_mem, 
            tau_syn=tau_syn, 
            activation=act_fn, 
            dropout_p=dropout_p,
            learn_tau_mem=True,
            learn_tau_syn=True,
            learn_tau_mem_hetero=True,
            learn_tau_syn_hetero=True
        ),
    )

    upstream_group = hidden_layer.output_group

    initializer.initialize(hidden_layer)

readout_group = model.add_group(
    ReadoutGroup(nb_classes, tau_mem=tau_readout, tau_syn=tau_syn, initial_state=-1e-2)
)

con_ro = model.add_connection(Connection(upstream_group, readout_group))
readout_initializer.initialize(con_ro)

# %% [markdown]
# Add monitors for spikes and membrane potential

# %%
for i in range(nb_hidden_layers):
    model.add_monitor(stork.monitors.SpikeCountMonitor(model.groups[1 + i]))

for i in range(nb_hidden_layers):
    model.add_monitor(stork.monitors.StateMonitor(model.groups[1 + i], "out"))

# %% [markdown]
# Choose loss function (We chose a maximum over time crossentropy loss, where the class is chosen according to the readout neuron that has the highest membrane potential over the simulation time)

# %%
loss_stack = SumOfSoftmaxCrossEntropy()

# %% [markdown]
# We select the SMORMS3 optimizer

# %%
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts
scheduler_kwargs = {
    "T_0": 10,
    "T_mult": 1,
    "eta_min": lr * 0.01,
    "last_epoch": -1,
}
opt = stork.optimizers.SMORMS3
generator = StandardGenerator(nb_workers=2)

# %%
model.configure(
    input=input_group,
    output=readout_group,
    loss_stack=loss_stack,
    generator=generator,
    optimizer=opt,
    optimizer_kwargs=dict(lr=lr),
    scheduler=scheduler,
    scheduler_kwargs=scheduler_kwargs,
    time_step=dt,
)

# %% [markdown]
# Before we train the model, we monitor the spikes (ca. 20s)

# %%
# Monitors spike counts before training
results = {}
res = model.monitor(test_dataset)
total_spikes_per_layer = [torch.sum(res[i]).item() for i in range(nb_hidden_layers)]
results["avg_layer_freq_init"] = [
    nb / len(test_dataset) / duration / nb_hidden_units for nb in total_spikes_per_layer
]

print(results)
# Out:
# {'avg_layer_freq_init': [12.561594670857522]}

# %%
model.groups[1].get_flattened_out_sequence().shape
# Out:
# torch.Size([216, 349, 1024])

# %%
plt.figure(dpi=150)
stork.plotting.plot_activity_snapshot(
    model, data=test_dataset, nb_samples=5, point_alpha=0.3
)

# %% [markdown]
# ## Train
#
# It takes around 50 min using a powerful GPU

# %%
history = model.fit_validate(
    train_dataset, valid_dataset, nb_epochs=50, verbose=True
)
# Out:
# 00  loss=0.0359 reg_loss=1.14e-05 acc=0.989 -- val_loss=0.0301 val_reg_loss=1.11e-05 val_acc=0.993 t_iter=19.40
# 01  loss=0.0311 reg_loss=1.15e-05 acc=0.988 -- val_loss=0.0624 val_reg_loss=1.11e-05 val_acc=0.982 t_iter=18.85
# 02  loss=0.0329 reg_loss=1.15e-05 acc=0.99 -- val_loss=0.0336 val_reg_loss=1.11e-05 val_acc=0.992 t_iter=18.62
# 03  loss=0.0316 reg_loss=1.14e-05 acc=0.988 -- val_loss=0.0406 val_reg_loss=1.12e-05 val_acc=0.989 t_iter=18.75
# 04  loss=0.0293 reg_loss=1.14e-05 acc=0.99 -- val_loss=0.0296 val_reg_loss=1.11e-05 val_acc=0.991 t_iter=18.75
# 05  loss=0.0319 reg_loss=1.14e-05 acc=0.99 -- val_loss=0.0354 val_reg_loss=1.11e-05 val_acc=0.993 t_iter=18.78
# 06  loss=0.0302 reg_loss=1.14e-05 acc=0.99 -- val_loss=0.0331 val_reg_loss=1.11e-05 val_acc=0.993 t_iter=18.64
# 07  loss=0.0329 reg_loss=1.14e-05 acc=0.99 -- val_loss=0.0446 val_reg_loss=1.11e-05 val_acc=0.991 t_iter=18.85
# 08  loss=0.0285 reg_loss=1.14e-05 acc=0.991 -- val_loss=0.0442 val_reg_loss=1.11e-05 val_acc=0.991 t_iter=18.97
# 09  loss=0.0242 reg_loss=1.15e-05 acc=0.991 -- val_loss=0.041 val_reg_loss=1.12e-05 val_acc=0.99 t_iter=20.02
# 10  loss=0.0403 reg_loss=1.14e-05 acc=0.987 -- val_loss=0.0339 val_reg_loss=1.11e-05 val_acc=0.992 t_iter=19.60
# 11  loss=0.0392 reg_loss=1.14e-05 acc=0.986 -- val_loss=0.0392 val_reg_loss=1.12e-05 val_acc=0.994 t_iter=19.55
# 12  loss=0.0275 reg_loss=1.14e-05 acc=0.99 -- val_loss=0.0413 val_reg_loss=1.11e-05 val_acc=0.99 t_iter=18.90
# 13  loss=0.032 reg_loss=1.14e-05 acc=0.989 -- val_loss=0.0387 val_reg_loss=1.11e-05 val_acc=0.991 t_iter=18.75
# 14  loss=0.0331 reg_loss=1.14e-05 acc=0.989 -- val_loss=0.0469 val_reg_loss=1.11e-05 val_acc=0.992 t_iter=18.61
# 15  loss=0.0377 reg_loss=1.14e-05 acc=0.987 -- val_loss=0.0512 val_reg_loss=1.11e-05 val_acc=0.986 t_iter=18.29
# 16  loss=0.0285 reg_loss=1.14e-05 acc=0.992 -- val_loss=0.0504 val_reg_loss=1.11e-05 val_acc=0.99 t_iter=18.55
# 17  loss=0.0358 reg_loss=1.14e-05 acc=0.988 -- val_loss=0.0419 val_reg_loss=1.11e-05 val_acc=0.992 t_iter=17.96
# 18  loss=0.0325 reg_loss=1.14e-05 acc=0.989 -- val_loss=0.0547 val_reg_loss=1.11e-05 val_acc=0.987 t_iter=18.10
# 19  loss=0.0382 reg_loss=1.14e-05 acc=0.988 -- val_loss=0.0488 val_reg_loss=1.11e-05 val_acc=0.99 t_iter=17.90
# 20  loss=0.0285 reg_loss=1.14e-05 acc=0.99 -- val_loss=0.0508 val_reg_loss=1.11e-05 val_acc=0.993 t_iter=17.81
# 21  loss=0.0288 reg_loss=1.14e-05 acc=0.99 -- val_loss=0.0393 val_reg_loss=1.11e-05 val_acc=0.991 t_iter=18.04
# 22  loss=0.037 reg_loss=1.13e-05 acc=0.987 -- val_loss=0.0408 val_reg_loss=1.1e-05 val_acc=0.99 t_iter=17.90
# 23  loss=0.0279 reg_loss=1.13e-05 acc=0.99 -- val_loss=0.0443 val_reg_loss=1.11e-05 val_acc=0.989 t_iter=17.65
# 24  loss=0.0308 reg_loss=1.13e-05 acc=0.989 -- val_loss=0.0495 val_reg_loss=1.09e-05 val_acc=0.989 t_iter=17.90
# 25  loss=0.0371 reg_loss=1.13e-05 acc=0.988 -- val_loss=0.0485 val_reg_loss=1.1e-05 val_acc=0.992 t_iter=17.75
# 26  loss=0.0303 reg_loss=1.12e-05 acc=0.989 -- val_loss=0.0404 val_reg_loss=1.1e-05 val_acc=0.991 t_iter=18.00
# 27  loss=0.0285 reg_loss=1.13e-05 acc=0.991 -- val_loss=0.0414 val_reg_loss=1.09e-05 val_acc=0.99 t_iter=18.08
# 28  loss=0.0329 reg_loss=1.13e-05 acc=0.989 -- val_loss=0.0403 val_reg_loss=1.1e-05 val_acc=0.991 t_iter=17.98
# 29  loss=0.0344 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.0448 val_reg_loss=1.1e-05 val_acc=0.992 t_iter=17.98
# 30  loss=0.0282 reg_loss=1.12e-05 acc=0.991 -- val_loss=0.0388 val_reg_loss=1.1e-05 val_acc=0.994 t_iter=17.70
# 31  loss=0.0278 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.0275 val_reg_loss=1.08e-05 val_acc=0.991 t_iter=17.89
# 32  loss=0.0327 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.0439 val_reg_loss=1.09e-05 val_acc=0.991 t_iter=17.93
# 33  loss=0.0321 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.037 val_reg_loss=1.09e-05 val_acc=0.992 t_iter=17.93
# 34  loss=0.0288 reg_loss=1.12e-05 acc=0.991 -- val_loss=0.0362 val_reg_loss=1.09e-05 val_acc=0.992 t_iter=17.97
# 35  loss=0.0335 reg_loss=1.12e-05 acc=0.989 -- val_loss=0.0481 val_reg_loss=1.09e-05 val_acc=0.989 t_iter=17.44
# 36  loss=0.0323 reg_loss=1.12e-05 acc=0.989 -- val_loss=0.0452 val_reg_loss=1.1e-05 val_acc=0.988 t_iter=17.78
# 37  loss=0.0259 reg_loss=1.12e-05 acc=0.991 -- val_loss=0.0458 val_reg_loss=1.09e-05 val_acc=0.991 t_iter=18.08
# 38  loss=0.0318 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.0313 val_reg_loss=1.08e-05 val_acc=0.991 t_iter=17.81
# 39  loss=0.0349 reg_loss=1.12e-05 acc=0.989 -- val_loss=0.0351 val_reg_loss=1.09e-05 val_acc=0.991 t_iter=17.94
# 40  loss=0.0308 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.0434 val_reg_loss=1.09e-05 val_acc=0.99 t_iter=17.88
# 41  loss=0.0313 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.0422 val_reg_loss=1.09e-05 val_acc=0.991 t_iter=17.81
# 42  loss=0.034 reg_loss=1.12e-05 acc=0.988 -- val_loss=0.0556 val_reg_loss=1.08e-05 val_acc=0.992 t_iter=17.57
# 43  loss=0.031 reg_loss=1.11e-05 acc=0.99 -- val_loss=0.0548 val_reg_loss=1.09e-05 val_acc=0.99 t_iter=18.03
# 44  loss=0.034 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.0446 val_reg_loss=1.08e-05 val_acc=0.991 t_iter=17.63
# 45  loss=0.0341 reg_loss=1.12e-05 acc=0.988 -- val_loss=0.0479 val_reg_loss=1.1e-05 val_acc=0.992 t_iter=17.62
# 46  loss=0.0264 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.04 val_reg_loss=1.09e-05 val_acc=0.989 t_iter=18.11
# 47  loss=0.0296 reg_loss=1.12e-05 acc=0.991 -- val_loss=0.0457 val_reg_loss=1.09e-05 val_acc=0.991 t_iter=17.95
# 48  loss=0.0291 reg_loss=1.12e-05 acc=0.99 -- val_loss=0.0422 val_reg_loss=1.09e-05 val_acc=0.991 t_iter=17.82
# 49  loss=0.0313 reg_loss=1.11e-05 acc=0.988 -- val_loss=0.0546 val_reg_loss=1.08e-05 val_acc=0.987 t_iter=17.83

# %%
if "train_loss" in results:
    results["train_loss"] += history["loss"].tolist()
    results["train_acc"] += history["acc"].tolist()
    results["valid_loss"] += history["val_loss"].tolist()
    results["valid_acc"] += history["val_acc"].tolist()
else:
    results["train_loss"] = history["loss"].tolist()
    results["train_acc"] = history["acc"].tolist()
    results["valid_loss"] = history["val_loss"].tolist()
    results["valid_acc"] = history["val_acc"].tolist()

# %% [markdown]
# Monitor the model again after training

# %%
res = model.monitor(test_dataset)
total_spikes_per_layer = [torch.sum(res[i]).item() for i in range(nb_hidden_layers)]
results["avg_layer_freq"] = [
    nb / len(test_dataset) / duration / nb_hidden_units for nb in total_spikes_per_layer
]

print(results["avg_layer_freq"])
# Out:
# [15.043696365471986]

# %% [markdown]
# ## Test

# %%
scores = model.evaluate(test_dataset).tolist()
results["test_loss"], _, results["test_acc"] = scores

# %%
fig, ax = plt.subplots(2, 2, figsize=(5, 3), dpi=150)

for i, n in enumerate(["train_loss", "train_acc", "valid_loss", "valid_acc"]):

    if i < 2:
        a = ax[0][i]
    else:
        a = ax[1][i - 2]

    a.plot(results[n], color="black")
    a.set_xlabel("Epochs")
    a.set_ylabel(n)

    if "loss" in n:
        a.set_yscale("log")

ax[0, 1].set_ylim(0, 1)
ax[1, 1].set_ylim(0, 1)

sns.despine()
plt.tight_layout()

print("Test loss: ", results["test_loss"])
print("Test acc.: ", results["test_acc"])
# Out:
# Test loss:  0.4002527958816952
# Test acc.:  0.9236593364197532

# %%
plt.figure(dpi=150)
stork.plotting.plot_activity_snapshot(
    model, data=test_dataset, nb_samples=5, point_alpha=0.3
)
