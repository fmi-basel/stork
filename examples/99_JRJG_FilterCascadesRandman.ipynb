# %% [markdown]
# # Train a shallow SNN on the Randman Dataset

# %%
import sys
sys.path.append("../../")

import numpy as np
import torch

import matplotlib.pyplot as plt
import seaborn as sns
from spiffyplots import MultiPanel

import stork.datasets
from stork.models import RecurrentSpikingModel
from stork.nodes import InputGroup, ReadoutGroup, LIFGroup, DeltaSynapseLIFGroup
from stork.connections import Connection, SuperConnection
from stork.generators import StandardGenerator
from stork.initializers import FluctuationDrivenCenteredNormalInitializer, KaimingNormalInitializer

# %% [markdown]
# ## Generate Dataset

# %% [markdown]
# Specify the Dataset Parameters

# %%
dim_manifold = 1
nb_classes = 10
nb_inputs = 20
nb_time_steps = 100
step_frac = 0.5
nb_samples = 1000
nb_spikes = 1
alpha = 1
randmanseed = 1
dt = 2e-3

duration = nb_time_steps*dt

# %%
data, labels = stork.datasets.make_tempo_randman(
    dim_manifold=dim_manifold,
    nb_classes=nb_classes,
    nb_units=nb_inputs,
    nb_steps=nb_time_steps,
    step_frac=step_frac,
    nb_samples=nb_samples,
    nb_spikes=nb_spikes,
    alpha=alpha,
    seed=randmanseed)

ds_kwargs = dict(
    nb_steps=nb_time_steps,
    nb_units=nb_inputs,
    time_scale=1.0
)

# Split into train, test and validation set
datasets = [stork.datasets.RasDataset(ds, **ds_kwargs) for ds in
            stork.datasets.split_dataset(data, labels, splits=[0.8, 0.1, 0.1], shuffle=False)]
ds_train, ds_valid, ds_test = datasets

# %%
fig, ax = plt.subplots(1,5, figsize=(10, 1.5), dpi=150)
for i in range(5):
    ax[i].imshow(np.transpose(ds_train[i][0]), cmap="binary", aspect="auto")
    ax[i].invert_yaxis()
    ax[i].set_xlabel("time step")
    ax[i].set_ylabel("Neuron Idx.")
    ax[i].set_title("label: " + str(ds_train[i][1]))

plt.tight_layout()
sns.despine()

# %% [markdown]
# ## Set up the model

# %%
# Model Parameters
batch_size = 250
beta = 20
device = torch.device("cuda:1")
dtype = torch.float


nb_hidden_units = 128
tau_mem = 20e-3
tau_syn = 10e-3
tau_readout = duration

tau_filter = 10e-3
nb_filters = 10

lr = 5e-3
nb_epochs = 50

# %%
act_fn = stork.activations.SuperSpike
act_fn.beta = beta
neuron_group = LIFGroup

model = RecurrentSpikingModel(
    batch_size,
    nb_time_steps,
    nb_inputs,
    device,
    dtype)

# %% [markdown]
# Add neuron groups

# %%
input_group = model.add_group(InputGroup(nb_inputs))
hidden_neurons = model.add_group(DeltaSynapseLIFGroup(
    nb_hidden_units,
    tau_mem=tau_mem,
    #tau_syn=tau_syn,
    activation=act_fn))
readout_group = model.add_group(ReadoutGroup(
    nb_classes,
    tau_mem=tau_readout,
    tau_syn=tau_syn,
    initial_state=-1e-2))

# %% [markdown]
# Add synapses between the neuron groups

# %%
con = model.add_connection(SuperConnection(input_group, hidden_neurons, tau_filter=tau_filter, nb_filters=nb_filters))
con_ro = model.add_connection(Connection(hidden_neurons, readout_group))

# %% [markdown]
# Add regularizers

# %%
# Define regularizer parameters (set regularizer strenght to 0, if you don't want to use them)
lowerBoundL2Strength = 100
lowerBoundL2Threshold = 1e-3
upperBoundL2Strength = 0.1
upperBoundL2Threshold = 4       # Regularizes spikecount: 4 spikes ~ 20 Hz in 200ms simulation time

# Define regularizer list
regs = []

regLB = stork.regularizers.LowerBoundL2(lowerBoundL2Strength, threshold=lowerBoundL2Threshold, dims=False)
regs.append(regLB)
regUB = stork.regularizers.UpperBoundL2(upperBoundL2Strength,threshold=upperBoundL2Threshold, dims=1)
regs.append(regUB)

# Add to neurons
hidden_neurons.regularizers.extend(regs)

# %% [markdown]
# We initialize the network in the Flucutation-Driven regime, with a target membrane potential standard deviation $\sigma_U=1.0$

# %%
sigma_u = 1.0
nu = nb_spikes/duration

initializer = KaimingNormalInitializer(gain=15.0)

con.init_parameters(initializer=initializer)
con_ro.init_parameters(initializer=initializer)

# %% [markdown]
# Add monitors for spikes and membrane potential

# %%
model.add_monitor(stork.monitors.SpikeCountMonitor(model.groups[1]))
model.add_monitor(stork.monitors.StateMonitor(model.groups[1], "out"))

# %% [markdown]
# Choose loss function (We chose a maximum over time crossentropy loss, where the class is chosen according to the readout neuron that has the highest membrane potential over the simulation time)

# %%
loss_stack = stork.loss_stacks.MaxOverTimeCrossEntropy()

# %% [markdown]
# We select the SMORMS3 optimizer

# %%
opt = stork.optimizers.SMORMS3
generator = StandardGenerator(nb_workers=2)

# %%
model.configure(input=input_group,
                output=readout_group,
                loss_stack=loss_stack,
                generator=generator,
                optimizer=opt,
                optimizer_kwargs=dict(lr=lr),
                time_step=dt)

# %% [markdown]
# Before we train the model, we monitor the spikes

# %%
# Monitors spike counts before training
res = model.monitor(ds_test)
total_spikes = torch.sum(res[0]).item()

results = {}
res = model.monitor(ds_test)
total_spikes_per_layer = [torch.sum(res[i]).item()for i in range(1)]
results["avg_layer_freq_init"] = [nb/len(ds_test)/duration/nb_hidden_units for nb in total_spikes_per_layer]

print(results)
# Out:
# {'avg_layer_freq_init': [9.665078124999999]}

# %%
plt.figure(dpi=150)
stork.plotting.plot_activity_snapshot(
    model,
    data=ds_test,
    point_alpha=0.8,
    show_predictions=False)

# %% [markdown]
# #### Get synaptic filters before training

# %%
before_weighted_filters = model.connections[0].get_filterbanks(T=duration)
before_weighted_filters_sum = before_weighted_filters.sum(-1)

# %%
fig = MultiPanel(grid=[1] * 10, figsize=(2.5, 8), dpi=150)

for idx in range(10):
    fig.panels[idx].hlines(0, before_weighted_filters_sum.shape[0], 0, color="black", linestyle="--")
    fig.panels[idx].plot(before_weighted_filters_sum[:, idx, 0], color='crimson')
    fig.panels[idx].axis('off')

# %% [markdown]
# ## Training
#
# takes around 13-20 minutes

# %%
history = model.fit_validate(
    ds_train,
    ds_valid,
    nb_epochs=nb_epochs,
    verbose=True)

results["train_loss"] = history["loss"].tolist()
results["train_acc"] = history["acc"].tolist()
results["valid_loss"] = history["val_loss"].tolist()
results["valid_acc"] = history["val_acc"].tolist()
# Out:
# 00  loss=2.48 reg_loss=3.8e-05 acc=0.157 -- val_loss=2.21 val_reg_loss=3.42e-05 val_acc=0.224 t_iter=4.14
# 01  loss=2.07 reg_loss=3e-05 acc=0.324 -- val_loss=1.94 val_reg_loss=2.52e-05 val_acc=0.393 t_iter=4.09
# 02  loss=1.82 reg_loss=2.21e-05 acc=0.465 -- val_loss=1.71 val_reg_loss=2.02e-05 val_acc=0.547 t_iter=3.88
# 03  loss=1.6 reg_loss=1.8e-05 acc=0.575 -- val_loss=1.53 val_reg_loss=1.58e-05 val_acc=0.613 t_iter=3.94
# 04  loss=1.43 reg_loss=1.48e-05 acc=0.649 -- val_loss=1.38 val_reg_loss=1.37e-05 val_acc=0.646 t_iter=4.02
# 05  loss=1.28 reg_loss=1.3e-05 acc=0.699 -- val_loss=1.24 val_reg_loss=1.22e-05 val_acc=0.714 t_iter=3.86
# 06  loss=1.16 reg_loss=1.18e-05 acc=0.739 -- val_loss=1.13 val_reg_loss=1.1e-05 val_acc=0.74 t_iter=3.90
# 07  loss=1.04 reg_loss=1.1e-05 acc=0.775 -- val_loss=1.01 val_reg_loss=1.07e-05 val_acc=0.773 t_iter=3.92
# 08  loss=0.941 reg_loss=1.03e-05 acc=0.81 -- val_loss=0.925 val_reg_loss=9.79e-06 val_acc=0.793 t_iter=3.84
# 09  loss=0.845 reg_loss=9.77e-06 acc=0.837 -- val_loss=0.836 val_reg_loss=9.1e-06 val_acc=0.83 t_iter=4.02
# 10  loss=0.759 reg_loss=9.02e-06 acc=0.859 -- val_loss=0.751 val_reg_loss=8.84e-06 val_acc=0.857 t_iter=3.96
# 11  loss=0.687 reg_loss=8.57e-06 acc=0.881 -- val_loss=0.69 val_reg_loss=8.51e-06 val_acc=0.869 t_iter=3.81
# 12  loss=0.616 reg_loss=8.23e-06 acc=0.899 -- val_loss=0.617 val_reg_loss=8.21e-06 val_acc=0.888 t_iter=4.04
# 13  loss=0.558 reg_loss=7.91e-06 acc=0.912 -- val_loss=0.563 val_reg_loss=7.55e-06 val_acc=0.899 t_iter=3.83
# 14  loss=0.501 reg_loss=7.37e-06 acc=0.925 -- val_loss=0.511 val_reg_loss=7.59e-06 val_acc=0.911 t_iter=3.98
# 15  loss=0.45 reg_loss=7.12e-06 acc=0.938 -- val_loss=0.46 val_reg_loss=7.19e-06 val_acc=0.924 t_iter=4.03
# 16  loss=0.407 reg_loss=6.93e-06 acc=0.944 -- val_loss=0.426 val_reg_loss=6.91e-06 val_acc=0.931 t_iter=4.00
# 17  loss=0.367 reg_loss=6.78e-06 acc=0.952 -- val_loss=0.379 val_reg_loss=6.94e-06 val_acc=0.938 t_iter=3.31
# 18  loss=0.333 reg_loss=6.69e-06 acc=0.958 -- val_loss=0.337 val_reg_loss=6.64e-06 val_acc=0.952 t_iter=3.99
# 19  loss=0.301 reg_loss=6.49e-06 acc=0.966 -- val_loss=0.309 val_reg_loss=6.58e-06 val_acc=0.957 t_iter=3.99
# 20  loss=0.271 reg_loss=6.33e-06 acc=0.972 -- val_loss=0.281 val_reg_loss=6.51e-06 val_acc=0.963 t_iter=3.91
# 21  loss=0.246 reg_loss=6.2e-06 acc=0.976 -- val_loss=0.258 val_reg_loss=6.25e-06 val_acc=0.967 t_iter=4.10
# 22  loss=0.225 reg_loss=6.1e-06 acc=0.979 -- val_loss=0.232 val_reg_loss=6.16e-06 val_acc=0.97 t_iter=4.01
# 23  loss=0.205 reg_loss=5.98e-06 acc=0.982 -- val_loss=0.212 val_reg_loss=5.95e-06 val_acc=0.977 t_iter=3.91
# 24  loss=0.185 reg_loss=5.8e-06 acc=0.984 -- val_loss=0.197 val_reg_loss=5.69e-06 val_acc=0.976 t_iter=3.97
# 25  loss=0.168 reg_loss=5.7e-06 acc=0.988 -- val_loss=0.183 val_reg_loss=5.6e-06 val_acc=0.982 t_iter=4.09
# 26  loss=0.155 reg_loss=5.79e-06 acc=0.987 -- val_loss=0.164 val_reg_loss=5.52e-06 val_acc=0.984 t_iter=3.95
# 27  loss=0.141 reg_loss=5.96e-06 acc=0.99 -- val_loss=0.149 val_reg_loss=5.39e-06 val_acc=0.988 t_iter=3.98
# 28  loss=0.128 reg_loss=6.11e-06 acc=0.992 -- val_loss=0.137 val_reg_loss=5.54e-06 val_acc=0.989 t_iter=3.94
# 29  loss=0.118 reg_loss=6.62e-06 acc=0.993 -- val_loss=0.125 val_reg_loss=5.73e-06 val_acc=0.991 t_iter=3.86
# 30  loss=0.107 reg_loss=7.39e-06 acc=0.994 -- val_loss=0.119 val_reg_loss=6.81e-06 val_acc=0.992 t_iter=4.04
# 31  loss=0.1 reg_loss=9.53e-06 acc=0.994 -- val_loss=0.107 val_reg_loss=8.98e-06 val_acc=0.995 t_iter=4.15
# 32  loss=0.0914 reg_loss=1.13e-05 acc=0.995 -- val_loss=0.0999 val_reg_loss=1.08e-05 val_acc=0.995 t_iter=3.96
# 33  loss=0.0836 reg_loss=1.59e-05 acc=0.996 -- val_loss=0.0912 val_reg_loss=1.46e-05 val_acc=0.994 t_iter=4.06
# 34  loss=0.0771 reg_loss=2.09e-05 acc=0.996 -- val_loss=0.0854 val_reg_loss=1.71e-05 val_acc=0.996 t_iter=3.88
# 35  loss=0.0708 reg_loss=2.74e-05 acc=0.997 -- val_loss=0.077 val_reg_loss=2.24e-05 val_acc=0.996 t_iter=3.67
# 36  loss=0.0645 reg_loss=3.28e-05 acc=0.997 -- val_loss=0.0719 val_reg_loss=2.74e-05 val_acc=0.997 t_iter=3.83
# 37  loss=0.0598 reg_loss=4.4e-05 acc=0.998 -- val_loss=0.0656 val_reg_loss=3.23e-05 val_acc=0.998 t_iter=3.85
# 38  loss=0.0554 reg_loss=5.6e-05 acc=0.999 -- val_loss=0.0608 val_reg_loss=4.2e-05 val_acc=0.997 t_iter=3.85
# 39  loss=0.0507 reg_loss=6.77e-05 acc=0.999 -- val_loss=0.0572 val_reg_loss=5.35e-05 val_acc=0.996 t_iter=3.92
# 40  loss=0.0464 reg_loss=7.74e-05 acc=0.999 -- val_loss=0.0533 val_reg_loss=6.87e-05 val_acc=0.997 t_iter=3.88
# 41  loss=0.0435 reg_loss=9.67e-05 acc=0.999 -- val_loss=0.0502 val_reg_loss=7.74e-05 val_acc=0.998 t_iter=3.85
# 42  loss=0.0401 reg_loss=0.000114 acc=0.999 -- val_loss=0.0472 val_reg_loss=8.03e-05 val_acc=0.998 t_iter=3.88
# 43  loss=0.0371 reg_loss=0.000126 acc=0.999 -- val_loss=0.0443 val_reg_loss=9.7e-05 val_acc=0.997 t_iter=3.56
# 44  loss=0.0347 reg_loss=0.000141 acc=0.999 -- val_loss=0.0426 val_reg_loss=0.000118 val_acc=0.998 t_iter=3.86
# 45  loss=0.0321 reg_loss=0.000159 acc=0.999 -- val_loss=0.0398 val_reg_loss=0.000128 val_acc=0.997 t_iter=3.87
# 46  loss=0.0298 reg_loss=0.000174 acc=1 -- val_loss=0.038 val_reg_loss=0.00015 val_acc=0.998 t_iter=3.21
# 47  loss=0.0278 reg_loss=0.000185 acc=1 -- val_loss=0.0355 val_reg_loss=0.000151 val_acc=0.998 t_iter=3.44
# 48  loss=0.0257 reg_loss=0.000199 acc=1 -- val_loss=0.0332 val_reg_loss=0.000159 val_acc=0.999 t_iter=3.86
# 49  loss=0.0239 reg_loss=0.00022 acc=1 -- val_loss=0.0321 val_reg_loss=0.00017 val_acc=0.997 t_iter=3.85

# %% [markdown]
# #### Monitor the model again after training

# %%
res = model.monitor(ds_test)
total_spikes_per_layer = [torch.sum(res[i]).item()for i in range(1)]
results["avg_layer_freq"] = [nb/len(ds_test)/duration/nb_hidden_units for nb in total_spikes_per_layer]

# %% [markdown]
# ## Test

# %%
scores = model.evaluate(ds_test).tolist()
results["test_loss"], _, results["test_acc"] = scores

# %%
fig, ax = plt.subplots(2,2, figsize=(5,3), dpi=150)

for i, n in enumerate(["train_loss", "train_acc", "valid_loss", "valid_acc"]):

    if i < 2:
        a = ax[0][i]
    else:
        a = ax[1][i-2]

    a.plot(results[n], color="black")
    a.set_xlabel("Epochs")
    a.set_ylabel(n)

ax[0, 1].set_ylim(0, 1)
ax[1, 1].set_ylim(0, 1)

sns.despine()
plt.tight_layout()

print("Test loss: ", results["test_loss"])
print("Test acc.: ", round(results["test_acc"]*100, 2), "%")
# Out:
# Test loss:  0.033495747949928045
# Test acc.:  99.9 %

# %%
plt.figure(dpi=150)
stork.plotting.plot_activity_snapshot(
    model,
    data=ds_test,
    point_alpha=0.8,
    show_predictions=False,
    nb_samples=5)

# %%
after_weighted_filters = model.connections[0].get_filterbanks(T=duration)
after_weighted_filters_sum = after_weighted_filters.sum(-1)

# %%
fig = MultiPanel(grid=[1] * 10, figsize=(2.5, 8), dpi=150)

for idx in range(10):
    fig.panels[idx].hlines(0, after_weighted_filters_sum.shape[0], 0, color="black", linestyle="--")
    fig.panels[idx].plot(after_weighted_filters_sum[:, idx, 0], color='navy')
    fig.panels[idx].plot(before_weighted_filters_sum[:, idx, 0], color='crimson')

    fig.panels[idx].axis('off')
