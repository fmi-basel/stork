# %% [markdown]
# # Train a shallow SNN on the Randman Dataset

# %%
import sys
sys.path.append('../')

import numpy as np
import torch

import matplotlib.pyplot as plt
import seaborn as sns

import stork.datasets
from stork.models import RecurrentSpikingModel
from stork.nodes import InputGroup, ReadoutGroup, LIFGroup, DelayGroup
from stork.connections import Connection
from stork.generators import StandardGenerator
from stork.initializers import FluctuationDrivenCenteredNormalInitializer
# Out:
# using delay stork version - filter cascades

# %% [markdown]
# ## Generate Dataset

# %% [markdown]
# Specify the Dataset Parameters

# %%
torch.manual_seed(12)


dim_manifold = 1
nb_classes = 10
nb_inputs = 20
nb_time_steps = 100
step_frac = 0.5
nb_samples = 1000
nb_spikes = 1
alpha = 1
randmanseed = 1
dt = 2e-3

duration = nb_time_steps*dt

# %%
data, labels = stork.datasets.make_tempo_randman(
    dim_manifold=dim_manifold,
    nb_classes=nb_classes,
    nb_units=nb_inputs,
    nb_steps=nb_time_steps,
    step_frac=step_frac,
    nb_samples=nb_samples,
    nb_spikes=nb_spikes,
    alpha=alpha,
    seed=randmanseed)

ds_kwargs = dict(
    nb_steps=nb_time_steps,
    nb_units=nb_inputs,
    time_scale=1.0
)

# Split into train, test and validation set
datasets = [stork.datasets.RasDataset(ds, **ds_kwargs) for ds in
            stork.datasets.split_dataset(data, labels, splits=[0.8, 0.1, 0.1], shuffle=False)]
ds_train, ds_valid, ds_test = datasets

print(len(ds_train), len(ds_valid), len(ds_test))
# Out:
# 8000 1000 1000

# %%
fig, ax = plt.subplots(1,5, figsize=(10, 1.5), dpi=150)
for i in range(5):
    ax[i].imshow(np.transpose(ds_train[i][0]), cmap="binary", aspect="auto")
    ax[i].invert_yaxis()
    ax[i].set_xlabel("time step")
    ax[i].set_ylabel("Neuron Idx.")
    ax[i].set_title("label: " + str(ds_train[i][1]))

plt.tight_layout()
sns.despine()

# %% [markdown]
# ## Set up the model

# %%
# Model Parameters
batch_size = 250
beta = 20
device = torch.device("cuda:0")
dtype = torch.float


nb_hidden_units = 128
tau_mem = 20e-3
tau_syn = 10e-3
tau_readout = duration

lr = 5e-3
nb_epochs = 50

# %%
act_fn = stork.activations.CustomSpike

act_fn.beta = beta
neuron_group = LIFGroup

model = RecurrentSpikingModel(batch_size, nb_time_steps, nb_inputs, device, dtype)

# %% [markdown]
# Add neuron groups

# %%
input_group = model.add_group(InputGroup(nb_inputs))
hidden_neurons = model.add_group(LIFGroup(
    nb_hidden_units,
    tau_mem=tau_mem,
    tau_syn=tau_syn,
    activation=act_fn))

# delay_neurons = model.add_group(DelayGroup(
#     src=hidden_neurons,
#     max_delay_timesteps=nb_time_steps//2,
# ))

hidden_neurons2 = model.add_group(LIFGroup(
    nb_hidden_units,
    tau_mem=tau_mem,
    tau_syn=tau_syn,
    activation=act_fn))

readout_group = model.add_group(ReadoutGroup(
    nb_classes,
    tau_mem=tau_readout,
    tau_syn=tau_syn,
    initial_state=-1e-2))

# %% [markdown]
# Add synapses between the neuron groups

# %%
con = model.add_connection(Connection(input_group, hidden_neurons))
con_hid = model.add_connection(Connection(hidden_neurons, hidden_neurons2))
con_ro = model.add_connection(Connection(hidden_neurons2, readout_group))

# %% [markdown]
# Add regularizers

# %%
# Define regularizer parameters (set regularizer strenght to 0, if you don't want to use them)
lowerBoundL2Strength = 100
lowerBoundL2Threshold = 1e-3
upperBoundL2Strength = 0.1
upperBoundL2Threshold = 4       # Regularizes spikecount: 4 spikes ~ 20 Hz in 200ms simulation time

# Define regularizer list
regs = []

regLB = stork.regularizers.LowerBoundL2(lowerBoundL2Strength, threshold=lowerBoundL2Threshold, dims=False)
regs.append(regLB)
regUB = stork.regularizers.UpperBoundL2(upperBoundL2Strength,threshold=upperBoundL2Threshold, dims=1)
regs.append(regUB)

# Add to neurons
hidden_neurons.regularizers.extend(regs)

# %% [markdown]
# We initialize the network in the Flucutation-Driven regime, with a target membrane potential standard deviation $\sigma_U=1.0$

# %%
sigma_u = 1.0
nu = nb_spikes/duration

initializer = FluctuationDrivenCenteredNormalInitializer(sigma_u = 1.0, nu = nu, timestep = dt)

con.init_parameters(initializer=initializer)
con_hid.init_parameters(initializer=initializer)
con_ro.init_parameters(initializer=initializer)

# %% [markdown]
# Add monitors for spikes and membrane potential

# %%
for g in model.groups:
    print(g.name)
# Out:
# Input
# LIFGroup
# LIFGroup
# Readout

# %%
model.add_monitor(stork.monitors.SpikeCountMonitor(model.groups[1]))
model.add_monitor(stork.monitors.StateMonitor(model.groups[1], "out"))

# %% [markdown]
# Choose loss function (We chose a maximum over time crossentropy loss, where the class is chosen according to the readout neuron that has the highest membrane potential over the simulation time)

# %%
loss_stack = stork.loss_stacks.MaxOverTimeCrossEntropy()

# %% [markdown]
# We select the SMORMS3 optimizer

# %%
opt = stork.optimizers.SMORMS3
generator = StandardGenerator(nb_workers=2)

# %%
model.configure(input=input_group,
                output=readout_group,
                loss_stack=loss_stack,
                generator=generator,
                optimizer=opt,
                optimizer_kwargs=dict(lr=lr),
                time_step=dt)

# %% [markdown]
# Before we train the model, we monitor the spikes

# %%
# Monitors spike counts before training
res = model.monitor(ds_test)
total_spikes = torch.sum(res[0]).item()

results = {}
res = model.monitor(ds_test)
total_spikes_per_layer = [torch.sum(res[i]).item()for i in range(1)]
results["avg_layer_freq_init"] = [nb/len(ds_test)/duration/nb_hidden_units for nb in total_spikes_per_layer]

print(results)
# Out:
# {'avg_layer_freq_init': [7.248671874999999]}

# %%
plt.figure(dpi=150)
stork.plotting.plot_activity_snapshot(
    model,
    data=ds_test,
    point_alpha=0.8,
    show_predictions=False)

# %% [markdown]
# ## Training
#
# takes around 13-20 minutes

# %%
# for name, param in model.named_parameters():
#     print(name, end="")
#     if "weight" in name:
#         # do not require grad
#         param.requires_grad = False
#         print(": no grad")
#     else:
#         print()

# %%
len(ds_train), len(ds_test)
# Out:
# (8000, 1000)

# %%
history = model.fit_validate(
    ds_train,
    ds_valid,
    nb_epochs=nb_epochs,
    verbose=True)
# Out:
# 00  loss=0.0463 reg_loss=6.1e-06 acc=0.997 -- val_loss=0.0934 val_reg_loss=6.01e-06 val_acc=0.973 t_iter=6.26
# 01  loss=0.0442 reg_loss=5.91e-06 acc=0.997 -- val_loss=0.0849 val_reg_loss=5.82e-06 val_acc=0.98 t_iter=5.80
# 02  loss=0.0429 reg_loss=5.74e-06 acc=0.998 -- val_loss=0.0853 val_reg_loss=5.63e-06 val_acc=0.979 t_iter=5.41
# 03  loss=0.0409 reg_loss=5.58e-06 acc=0.998 -- val_loss=0.0815 val_reg_loss=5.43e-06 val_acc=0.981 t_iter=5.42
# 04  loss=0.0401 reg_loss=5.39e-06 acc=0.998 -- val_loss=0.0814 val_reg_loss=5.25e-06 val_acc=0.982 t_iter=6.07
# 05  loss=0.0374 reg_loss=5.23e-06 acc=0.998 -- val_loss=0.0788 val_reg_loss=5.09e-06 val_acc=0.981 t_iter=5.73
# 06  loss=0.0368 reg_loss=5.07e-06 acc=0.998 -- val_loss=0.0728 val_reg_loss=4.91e-06 val_acc=0.983 t_iter=6.51
# 07  loss=0.0343 reg_loss=4.89e-06 acc=0.998 -- val_loss=0.0738 val_reg_loss=4.75e-06 val_acc=0.978 t_iter=5.87
# 08  loss=0.0329 reg_loss=4.69e-06 acc=0.999 -- val_loss=0.0759 val_reg_loss=4.59e-06 val_acc=0.978 t_iter=5.90
# 09  loss=0.0324 reg_loss=4.54e-06 acc=0.999 -- val_loss=0.0814 val_reg_loss=4.42e-06 val_acc=0.977 t_iter=5.85
# 10  loss=0.0318 reg_loss=4.37e-06 acc=0.998 -- val_loss=0.081 val_reg_loss=4.27e-06 val_acc=0.979 t_iter=6.71
# 11  loss=0.0302 reg_loss=4.24e-06 acc=0.999 -- val_loss=0.0769 val_reg_loss=4.16e-06 val_acc=0.98 t_iter=6.03
# 12  loss=0.0299 reg_loss=4.13e-06 acc=0.998 -- val_loss=0.0719 val_reg_loss=3.99e-06 val_acc=0.98 t_iter=6.62
# 13  loss=0.0292 reg_loss=3.97e-06 acc=0.999 -- val_loss=0.0729 val_reg_loss=3.87e-06 val_acc=0.981 t_iter=6.67
# 14  loss=0.0276 reg_loss=3.85e-06 acc=0.999 -- val_loss=0.0729 val_reg_loss=3.73e-06 val_acc=0.976 t_iter=5.61
# 15  loss=0.0262 reg_loss=3.73e-06 acc=0.999 -- val_loss=0.0741 val_reg_loss=3.62e-06 val_acc=0.973 t_iter=5.31
# 16  loss=0.0251 reg_loss=3.62e-06 acc=0.999 -- val_loss=0.0767 val_reg_loss=3.51e-06 val_acc=0.971 t_iter=5.93
# 17  loss=0.024 reg_loss=3.5e-06 acc=0.999 -- val_loss=0.0723 val_reg_loss=3.44e-06 val_acc=0.976 t_iter=6.10
# 18  loss=0.0232 reg_loss=3.39e-06 acc=0.999 -- val_loss=0.076 val_reg_loss=3.33e-06 val_acc=0.973 t_iter=5.90
# 19  loss=0.0226 reg_loss=3.3e-06 acc=1 -- val_loss=0.0724 val_reg_loss=3.22e-06 val_acc=0.977 t_iter=6.25
# 20  loss=0.0216 reg_loss=3.21e-06 acc=0.999 -- val_loss=0.07 val_reg_loss=3.15e-06 val_acc=0.977 t_iter=5.43
# 21  loss=0.0206 reg_loss=3.12e-06 acc=1 -- val_loss=0.07 val_reg_loss=3.06e-06 val_acc=0.98 t_iter=6.01
# 22  loss=0.0203 reg_loss=3.04e-06 acc=0.999 -- val_loss=0.0663 val_reg_loss=2.98e-06 val_acc=0.979 t_iter=5.84
# 23  loss=0.0201 reg_loss=2.96e-06 acc=0.999 -- val_loss=0.0675 val_reg_loss=2.88e-06 val_acc=0.98 t_iter=5.82
# 24  loss=0.0187 reg_loss=2.87e-06 acc=1 -- val_loss=0.0644 val_reg_loss=2.81e-06 val_acc=0.978 t_iter=5.84
# 25  loss=0.0186 reg_loss=2.8e-06 acc=0.999 -- val_loss=0.066 val_reg_loss=2.74e-06 val_acc=0.978 t_iter=5.73
# 26  loss=0.0181 reg_loss=2.73e-06 acc=1 -- val_loss=0.0598 val_reg_loss=2.68e-06 val_acc=0.983 t_iter=6.12
# 27  loss=0.018 reg_loss=2.67e-06 acc=0.999 -- val_loss=0.0595 val_reg_loss=2.61e-06 val_acc=0.979 t_iter=6.00
# 28  loss=0.0169 reg_loss=2.6e-06 acc=0.999 -- val_loss=0.0628 val_reg_loss=2.54e-06 val_acc=0.979 t_iter=6.01
# 29  loss=0.0159 reg_loss=2.52e-06 acc=1 -- val_loss=0.0576 val_reg_loss=2.46e-06 val_acc=0.981 t_iter=6.35
# 30  loss=0.0156 reg_loss=2.43e-06 acc=1 -- val_loss=0.0549 val_reg_loss=2.37e-06 val_acc=0.982 t_iter=5.90
# 31  loss=0.0152 reg_loss=2.36e-06 acc=1 -- val_loss=0.0574 val_reg_loss=2.31e-06 val_acc=0.983 t_iter=5.99
# 32  loss=0.0149 reg_loss=2.28e-06 acc=1 -- val_loss=0.0543 val_reg_loss=2.2e-06 val_acc=0.982 t_iter=5.97
# 33  loss=0.0143 reg_loss=2.19e-06 acc=1 -- val_loss=0.0588 val_reg_loss=2.09e-06 val_acc=0.98 t_iter=6.29
# 34  loss=0.0139 reg_loss=2.09e-06 acc=1 -- val_loss=0.0564 val_reg_loss=1.99e-06 val_acc=0.981 t_iter=6.15
# 35  loss=0.0127 reg_loss=2e-06 acc=1 -- val_loss=0.0556 val_reg_loss=1.88e-06 val_acc=0.982 t_iter=5.83
# 36  loss=0.0124 reg_loss=1.88e-06 acc=1 -- val_loss=0.0572 val_reg_loss=1.76e-06 val_acc=0.986 t_iter=6.80
# 37  loss=0.0126 reg_loss=1.76e-06 acc=1 -- val_loss=0.0558 val_reg_loss=1.66e-06 val_acc=0.986 t_iter=5.83
# 38  loss=0.0128 reg_loss=1.65e-06 acc=1 -- val_loss=0.0542 val_reg_loss=1.57e-06 val_acc=0.983 t_iter=5.68
# 39  loss=0.0122 reg_loss=1.6e-06 acc=0.999 -- val_loss=0.0506 val_reg_loss=1.55e-06 val_acc=0.984 t_iter=5.38
# 40  loss=0.0121 reg_loss=1.54e-06 acc=1 -- val_loss=0.055 val_reg_loss=1.48e-06 val_acc=0.981 t_iter=6.36
# 41  loss=0.0118 reg_loss=1.49e-06 acc=1 -- val_loss=0.0552 val_reg_loss=1.45e-06 val_acc=0.981 t_iter=6.20
# 42  loss=0.0111 reg_loss=1.44e-06 acc=1 -- val_loss=0.0601 val_reg_loss=1.38e-06 val_acc=0.978 t_iter=6.04
# 43  loss=0.0108 reg_loss=1.38e-06 acc=1 -- val_loss=0.0548 val_reg_loss=1.34e-06 val_acc=0.985 t_iter=5.91
# 44  loss=0.0106 reg_loss=1.34e-06 acc=1 -- val_loss=0.0526 val_reg_loss=1.31e-06 val_acc=0.987 t_iter=5.96
# 45  loss=0.0101 reg_loss=1.31e-06 acc=1 -- val_loss=0.0541 val_reg_loss=1.27e-06 val_acc=0.983 t_iter=5.43
# 46  loss=0.00996 reg_loss=1.26e-06 acc=1 -- val_loss=0.0548 val_reg_loss=1.23e-06 val_acc=0.982 t_iter=5.84
# 47  loss=0.00912 reg_loss=1.23e-06 acc=1 -- val_loss=0.0493 val_reg_loss=1.21e-06 val_acc=0.983 t_iter=5.54
# 48  loss=0.00893 reg_loss=1.2e-06 acc=1 -- val_loss=0.0474 val_reg_loss=1.17e-06 val_acc=0.983 t_iter=5.75
# 49  loss=0.0086 reg_loss=1.18e-06 acc=1 -- val_loss=0.0472 val_reg_loss=1.15e-06 val_acc=0.984 t_iter=5.85

# %%
for key, val in history.items():
    if key in results:
        results[key] += val.tolist()
    else:
        results[key] = val.tolist()

# %%
for con in model.connections:
    print(con.name, torch.sum(con.op.weight.grad))
# Out:
#  tensor(-0.0078, device='cuda:0')
#  tensor(0.0339, device='cuda:0')
#  tensor(-0.0097, device='cuda:0')

# %%
for name, param in model.named_parameters():
    print(name, param.requires_grad)
# Out:
# con1.op.weight True
# con2.op.weight True
# con3.op.weight True

# %%
from graphviz import Digraph
import torch
from torch.autograd import Variable

from torchviz import make_dot

# %%
# make_dot(model.groups[2].delays,  params=dict(model.named_parameters()), show_attrs=False, show_saved=False)

# %%
# make_dot(model.groups[2].out,  params=dict(model.named_parameters()))

# %% [markdown]
# #### Monitor the model again after training

# %%
res = model.monitor(ds_test)
total_spikes_per_layer = [torch.sum(res[i]).item()for i in range(1)]
results["avg_layer_freq"] = [nb/len(ds_test)/duration/nb_hidden_units for nb in total_spikes_per_layer]

# %% [markdown]
# ## Test

# %%
scores = model.evaluate(ds_test).tolist()
l, _, a = scores
if "test_loss" in results:
    results["test_loss"].append(l)
    results["test_acc"].append(a)
else:
    results["test_loss"] = [l]
    results["test_acc"]  = [a]

# %%
fig, ax = plt.subplots(2,2, figsize=(5,3), dpi=150)

for i, n in enumerate(["loss", "acc", "val_loss", "val_acc"]):

    if i < 2:
        a = ax[0][i]
    else:
        a = ax[1][i-2]

    a.plot(results[n], color="black")
    a.set_xlabel("Epochs")
    a.set_ylabel(n)

ax[0, 1].set_ylim(0, 1)
ax[1, 1].set_ylim(0, 1)

sns.despine()
plt.tight_layout()

print("Test loss: ", results["test_loss"][-1])
print("Test acc.: ", round(results["test_acc"][-1]*100, 2), "%")
# Out:
# Test loss:  0.05392063036561012
# Test acc.:  98.2 %

# %%
plt.figure(dpi=150)
stork.plotting.plot_activity_snapshot(
    model,
    data=ds_test,
    point_alpha=0.8,
    show_predictions=False,
    nb_samples=5)
